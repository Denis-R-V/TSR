# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Denis-R-V/TSR/blob/main/notebooks/4.1.classifier_make_background.ipynb)

# %% [markdown]
# # Система распознавания дорожных знаков на датасете RTSD

# %% [markdown]
# ## Подготовка ложноположительных детекций для обучения классификатора (класс background)

# %%
# если работаем в колабе - монтируем диск, ставим fiftyone и kaggle
try:
    from google.colab import drive
    drive.mount('/content/drive')

    # !pip install fiftyone -q
    # !pip install kaggle -q
    
    colab=True
except:
    colab=False

# %%
import json
import os

import torch
import torchvision
from torchvision.transforms import functional as func
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

from PIL import Image
import fiftyone as fo

# %%
# если работаем в колабе - скачиваем и распаковываем датасет
if colab==True:
    # !mkdir ~/.kaggle
    # !cp /content/drive/MyDrive/kaggle.json ~/.kaggle/kaggle.json
    
    # !kaggle datasets download watchman/rtsd-dataset
    
    # !mkdir -p data/raw/RTSD
    # !unzip -q rtsd-dataset.zip -d ./data/raw/RTSD/
    # !rm rtsd-dataset.zip
    # !cp -r data/raw/RTSD/rtsd-frames/rtsd-frames/ data/raw/RTSD
    # !rm -r data/raw/RTSD/rtsd-frames/rtsd-frames/

# %% [markdown]
# ### Пути и параметры

# %%
dataset_path = 'data/raw/RTSD' if colab else os.path.join('..', 'data', 'raw', 'RTSD')
models_path = '../models' if colab == False else '../content/drive/MyDrive/TSR/models'
metrics_path = 'data/metrics' if colab else os.path.join('..', 'data', 'metrics')

device_id = 0
if torch.cuda.is_available() == True:
    device = f'cuda:{device_id}'
#elif torch.backends.mps.is_available() == True:
#    device = 'mps'
else:
    device = 'cpu'

#model_name = 'mobilenet_v3_320_b8'          # еще не обучена
#model_name = 'mobilenet_v3_b8'
#model_name = 'resnet50_b8'
#model_name = 'resnet50_v2_b8'
#model_name = 'resnet50_augmented_b8'
#model_name = 'resnet50_v2_augmented_b8'
model_name = 'resnet50_augmented_b16'
#model_name = 'resnet50_v2_augmented_b16'

epoch = 5      # эпоха для загрузки весов

# %% [markdown]
# ### Загрузка детектора

# %%
def load_model_detection(model_name, num_classes, epoch):
    # load model
    if (model_name == 'resnet50_b8') or (model_name == 'resnet50_augmented_b8') or (model_name == 'resnet50_augmented_b16'):
        model = torchvision.models.detection.fasterrcnn_resnet50_fpn(weights=None)
        print("Загружена модель resnet50")
    elif (model_name == 'resnet50_v2_b8') or (model_name == 'resnet50_v2_augmented_b8') or (model_name == 'resnet50_v2_augmented_b16'):
        model =torchvision.models.detection.fasterrcnn_resnet50_fpn_v2(weights=None)
        print("Загружена модель resnet50_v2")
    elif model_name == 'mobilenet_v3_b8':
        model =torchvision.models.detection.fasterrcnn_mobilenet_v3_large_fpn(weights=None)
        print("Загружена модель mobilenet_v3")
    elif model_name == 'mobilenet_v3_320_b8':    
        model =torchvision.models.detection.fasterrcnn_mobilenet_v3_large_320_fpn(weights=None)
        print("Загружена модель mobilenet_v3_320")
    else:
        print("Неверно указано название модели")
    # get number of input features for the classifier
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    # replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)
    
    # Загрузка весов модели
    checkpoint = torch.load(os.path.join(models_path, f'detector_{model_name}_chkpt_{epoch}.pth'), map_location=device)
    model.load_state_dict(checkpoint['model_state_dict'])
    print(f"Для модели {model_name} загружены веса эпохи {epoch}")
    model.eval()
    return model

model = load_model_detection(model_name, num_classes=2, epoch=epoch).to(device)
# Out:
# Загружена модель resnet50
# Для модели resnet50_augmented_b16 загружены веса эпохи 5

# %% [markdown]
# ### Загрузка обучающего датасета (reduced)

# %%
#Load train dataset COCO

# The directiry containing the source images
data_path = dataset_path      # можно не указывать, если в JSON путь совпадает

# The path yo the COCO labels JSON file
train_anno_reduced_file = "train_anno_reduced_bin_class.json"
val_anno_path = os.path.join(dataset_path, train_anno_reduced_file)

# Import the dataset
train_reduced_dataset = fo.Dataset.from_dir(
    dataset_type=fo.types.COCODetectionDataset,
    data_path=data_path,
    labels_path=val_anno_path
)
# Out:
#  100% |███████████████| 1889/1889 [2.4s elapsed, 0s remaining, 795.7 samples/s]

# %%
#predictions_view = train_reduced_dataset.take(50, seed=42)

# %%
# Add and evaluating Faster-RCNN detections
# Faster-RCNN detections can be calculated and added to every sample of the dataset in a new field

#classes = predictions_view.default_classes
classes = train_reduced_dataset.default_classes
# Add predictions
#for sample in predictions_view:
model.eval()
for i, sample in enumerate(train_reduced_dataset):
    image = Image.open(sample.filepath)
    image = func.to_tensor(image).to(device)
    c,h,w = image.shape
    preds = model([image])[0]
    labels = preds['labels'].cpu().detach().numpy()
    scores = preds['scores'].cpu().detach().numpy()
    boxes = preds['boxes'].cpu().detach().numpy()
    detections = []
    for label, score, box in zip (labels, scores, boxes):
        # Compute relative bounding box coordinates
        x1, y1, x2, y2 = box
        rel_box = [x1/w, y1/h, (x2-x1)/w, (y2-y1)/h]
        detections.append(fo.Detection(label=classes[label],
                                        bounding_box=rel_box,
                                        confidence=score
                                        )
                            )
    sample['faster_rcnn'] = fo.Detections(detections=detections)
    sample.save()
    if i % 100 == 0:
            print(f"\tОбработано {i} из {train_reduced_dataset.__len__()} сэмплов.")
# Out:
# 	Обработано 0 из 1889 сэмплов.
# 	Обработано 100 из 1889 сэмплов.
# 	Обработано 200 из 1889 сэмплов.
# 	Обработано 300 из 1889 сэмплов.
# 	Обработано 400 из 1889 сэмплов.
# 	Обработано 500 из 1889 сэмплов.
# 	Обработано 600 из 1889 сэмплов.
# 	Обработано 700 из 1889 сэмплов.
# 	Обработано 800 из 1889 сэмплов.
# 	Обработано 900 из 1889 сэмплов.
# 	Обработано 1000 из 1889 сэмплов.
# 	Обработано 1100 из 1889 сэмплов.
# 	Обработано 1200 из 1889 сэмплов.
# 	Обработано 1300 из 1889 сэмплов.
# 	Обработано 1400 из 1889 сэмплов.
# 	Обработано 1500 из 1889 сэмплов.
# 	Обработано 1600 из 1889 сэмплов.
# 	Обработано 1700 из 1889 сэмплов.
# 	Обработано 1800 из 1889 сэмплов.

# %%
# Evaluate the predictions in the `faster_rcnn` field of our `high_conf_view`
# with respect to the objects in the `ground_truth` field
results = train_reduced_dataset.evaluate_detections(
    "faster_rcnn",
    gt_field="detections",
    eval_key="eval",
    compute_mAP=True,
)
# Out:
# Evaluating detections...
#  100% |███████████████| 1889/1889 [8.2s elapsed, 0s remaining, 270.0 samples/s]
# Performing IoU sweep...
#  100% |███████████████| 1889/1889 [8.3s elapsed, 0s remaining, 248.7 samples/s]

# %%
# Для faster_rcnn оставляем только FP детекции
fp_detections = train_reduced_dataset.filter_labels("faster_rcnn", fo.ViewField("eval") == "fp")

# %%
session = fo.launch_app(fp_detections)

# %%
# Сохраняем файл с аннотацией FP Детекций
fp_detections.export(
    export_dir=os.path.join(dataset_path),
    dataset_type=fo.types.COCODetectionDataset,
    labels_path='train_anno_reduced_fp_detections.json',
    label_field='faster_rcnn',
    )
# Out:
# Directory 'data' already exists; export will be merged with existing files
#  100% |███████████████| 1576/1576 [5.1s elapsed, 0s remaining, 348.1 samples/s]

# %%
# Поменяем ссылки на существующие изображения в файле аннотации
# Каталог с сохраненными изображениями (dataset_path/data) можено удалить

with open(os.path.join(dataset_path, 'train_anno_reduced_fp_detections.json'), 'r') as read_file:
    train_anno_reduced_fp_detections = json.load(read_file)
read_file.close()
train_anno_reduced_fp_detections['images']

for i in range(len(train_anno_reduced_fp_detections['images'])):
    train_anno_reduced_fp_detections['images'][i]['file_name'] = 'rtsd-frames/' + train_anno_reduced_fp_detections['images'][i]['file_name']
train_anno_reduced_fp_detections['images']

with open(os.path.join(dataset_path, 'train_anno_reduced_fp_detections.json'), 'w') as f:
    json.dump(train_anno_reduced_fp_detections, f)#ensure_ascii=False, indent=4)
f.close()

# %%
# Смотрим итоговую аннотацию
with open(os.path.join(dataset_path, 'train_anno_reduced_fp_detections.json'), 'r') as read_file:
    train_anno_reduced_fp_detections = json.load(read_file)
read_file.close()
train_anno_reduced_fp_detections['images']
# Out:
# [{'id': 1,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_16_49.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 2,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_16_50.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 3,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_16_51.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 4,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_16_56.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 5,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_17_01.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 6,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_17_04.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 7,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_17_05.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 8,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_17_08.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 9,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_17_09.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 10,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_18_35.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 11,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_18_36.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 12,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_18_38.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 13,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_18_39.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 14,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_18_44.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 15,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_18_45.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 16,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_18_53.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 17,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_19_02.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 18,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_19_07.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 19,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_26_06.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 20,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_26_07.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 21,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_26_09.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 22,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_26_10.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 23,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_26_11.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 24,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_26_16.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 25,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_26_18.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 26,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_26_20.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 27,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_26_22.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 28,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_26_34.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 29,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_28_00.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 30,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_28_01.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 31,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_28_03.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 32,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_28_08.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 33,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_28_10.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 34,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_28_12.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 35,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_28_15.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 36,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_28_20.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 37,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_28_21.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 38,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_28_25.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 39,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_28_26.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 40,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_28_27.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 41,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_28_28.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 42,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_28_29.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 43,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_28_30.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 44,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_29_12.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 45,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_30_34.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 46,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_31_08.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 47,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_31_12.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 48,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_31_22.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 49,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_31_23.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 50,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_31_27.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 51,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_42_32.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 52,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_56_25.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 53,
#   'file_name': 'rtsd-frames/autosave01_02_2012_10_11_31.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 54,
#   'file_name': 'rtsd-frames/autosave01_02_2012_10_14_41.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 55,
#   'file_name': 'rtsd-frames/autosave01_02_2012_10_15_51.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 56,
#   'file_name': 'rtsd-frames/autosave01_02_2012_10_15_52.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 57,
#   'file_name': 'rtsd-frames/autosave01_02_2012_10_16_50.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 58,
#   'file_name': 'rtsd-frames/autosave01_02_2012_10_24_47.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 59,
#   'file_name': 'rtsd-frames/autosave01_02_2012_10_26_41.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id':
0.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  ...]

# %% [markdown]
# ### Отбор реальных FP детекций

# %% [markdown]
# Загрузка датасета с FP детекциями

# %%
# загрузка датасета

# The directiry containing the source images
data_path = dataset_path     # можно не указывать, если в JSON путь совпадает

# The path yo the COCO labels JSON file
labels_file = 'train_anno_reduced_fp_detections.json'
labels_path = os.path.join(dataset_path, labels_file)


# Import the dataset
fp_detections_dataset = fo.Dataset.from_dir(
    dataset_type=fo.types.COCODetectionDataset,
    data_path=data_path,
    labels_path=labels_path
)
# Out:
#  100% |███████████████| 1576/1576 [4.6s elapsed, 0s remaining, 363.5 samples/s]

# %%
# Визуализация набора данных
# Для FP детекций (пойдут в фон классификатора) необходимо добавить label 'background'

session = fo.launch_app(fp_detections_dataset)

# %%
fp_detections_dataset.save
# Out:
# <bound method Dataset.save of Name:        2023.01.22.20.20.26
# Media type:  image
# Num samples: 1576
# Persistent:  False
# Tags:        []
# Sample fields:
#     id:         fiftyone.core.fields.ObjectIdField
#     filepath:   fiftyone.core.fields.StringField
#     tags:       fiftyone.core.fields.ListField(fiftyone.core.fields.StringField)
#     metadata:   fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.metadata.ImageMetadata)
#     detections: fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)>

# %%
for sample in fp_detections_dataset:
    detections = []
    for i in range(len(sample.detections.detections)):
        if 'background' in sample.detections.detections[i]['tags']:
            label = sample.detections.detections[i]['label']
            box = sample.detections.detections[i]['bounding_box']
            score = sample.detections.detections[i]['confidence']
            detections.append(fo.Detection(label=label,
                                        bounding_box=box,
                                        confidence=score
                                        )
                            )
        sample['background'] = fo.Detections(detections=detections)
        sample.save()

# %%
# Сохраняем файл с аннотацией FP Детекций
dataset_background = fp_detections_dataset.filter_labels('background', fo.ViewField("label") == "sign")
dataset_background.export(
    export_dir=os.path.join(dataset_path),
    dataset_type=fo.types.COCODetectionDataset,
    labels_path='train_anno_reducer_background.json',
    label_field='background',
)
# Out:
# Directory 'data' already exists; export will be merged with existing files
#  100% |█████████████████| 590/590 [1.8s elapsed, 0s remaining, 351.8 samples/s]

# %%
# Поменяем ссылки на существующие изображения в файле аннотации
# Каталог с сохраненными изображениями (dataset_path/data) можено удалить

with open(os.path.join(dataset_path, 'train_anno_reducer_background.json'), 'r') as read_file:
    train_anno_reducer_background = json.load(read_file)
read_file.close()
train_anno_reducer_background['images']

for i in range(len(train_anno_reducer_background['images'])):
    train_anno_reducer_background['images'][i]['file_name'] = 'rtsd-frames/' + train_anno_reducer_background['images'][i]['file_name']
train_anno_reducer_background['images']

with open(os.path.join(dataset_path, 'train_anno_reducer_background.json'), 'w') as f:
    json.dump(train_anno_reducer_background, f)#ensure_ascii=False, indent=4)
f.close()

# %%
# загрузка датасета

# The directiry containing the source images
data_path = dataset_path      # можно не указывать, если в JSON путь совпадает

# The path yo the COCO labels JSON file
labels_file = "train_anno_reducer_background.json"
labels_path = os.path.join(dataset_path, labels_file)


# Import the dataset
dataset_background = fo.Dataset.from_dir(
    dataset_type=fo.types.COCODetectionDataset,
    data_path=data_path,
    labels_path=labels_path
)
# Out:
#  100% |█████████████████| 590/590 [822.8ms elapsed, 0s remaining, 717.0 samples/s]

# %%
session = fo.launch_app(dataset_background)

# %% [markdown]
# ### Загрузка валидационного датасета

# %%
#Load val dataset COCO

# The directiry containing the source images
data_path = dataset_path      # можно не указывать, если в JSON путь совпадает

# The path yo the COCO labels JSON file
val_anno_file = "val_anno_bin_class.json"
val_anno_path = os.path.join(dataset_path, val_anno_file)

# Import the dataset
val_dataset = fo.Dataset.from_dir(
    dataset_type=fo.types.COCODetectionDataset,
    data_path=data_path,
    labels_path=val_anno_path
)
# Out:
#  100% |███████████████| 5000/5000 [7.9s elapsed, 0s remaining, 704.7 samples/s]

# %%
#predictions_view = val_dataset.take(50, seed=42)

# %%
# Add and evaluating Faster-RCNN detections
# Faster-RCNN detections can be calculated and added to every sample of the dataset in a new field

#classes = predictions_view.default_classes
classes = val_dataset.default_classes
# Add predictions
#for sample in predictions_view:
model.eval()
for i, sample in enumerate(val_dataset):
    image = Image.open(sample.filepath)
    image = func.to_tensor(image).to(device)
    c,h,w = image.shape
    preds = model([image])[0]
    labels = preds['labels'].cpu().detach().numpy()
    scores = preds['scores'].cpu().detach().numpy()
    boxes = preds['boxes'].cpu().detach().numpy()
    detections = []
    for label, score, box in zip (labels, scores, boxes):
        # Compute relative bounding box coordinates
        x1, y1, x2, y2 = box
        rel_box = [x1/w, y1/h, (x2-x1)/w, (y2-y1)/h]
        detections.append(fo.Detection(label=classes[label],
                                        bounding_box=rel_box,
                                        confidence=score
                                        )
                            )
    sample['faster_rcnn'] = fo.Detections(detections=detections)
    sample.save()
    if i % 100 == 0:
            print(f"\tОбработано {i} из {val_dataset.__len__()} сэмплов.")
# Out:
# 	Обработано 0 из 5000 сэмплов.
# 	Обработано 100 из 5000 сэмплов.
# 	Обработано 200 из 5000 сэмплов.
# 	Обработано 300 из 5000 сэмплов.
# 	Обработано 400 из 5000 сэмплов.
# 	Обработано 500 из 5000 сэмплов.
# 	Обработано 600 из 5000 сэмплов.
# 	Обработано 700 из 5000 сэмплов.
# 	Обработано 800 из 5000 сэмплов.
# 	Обработано 900 из 5000 сэмплов.
# 	Обработано 1000 из 5000 сэмплов.
# 	Обработано 1100 из 5000 сэмплов.
# 	Обработано 1200 из 5000 сэмплов.
# 	Обработано 1300 из 5000 сэмплов.
# 	Обработано 1400 из 5000 сэмплов.
# 	Обработано 1500 из 5000 сэмплов.
# 	Обработано 1600 из 5000 сэмплов.
# 	Обработано 1700 из 5000 сэмплов.
# 	Обработано 1800 из 5000 сэмплов.
# 	Обработано 1900 из 5000 сэмплов.
# 	Обработано 2000 из 5000 сэмплов.
# 	Обработано 2100 из 5000 сэмплов.
# 	Обработано 2200 из 5000 сэмплов.
# 	Обработано 2300 из 5000 сэмплов.
# 	Обработано 2400 из 5000 сэмплов.
# 	Обработано 2500 из 5000 сэмплов.
# 	Обработано 2600 из 5000 сэмплов.
# 	Обработано 2700 из 5000 сэмплов.
# 	Обработано 2800 из 5000 сэмплов.
# 	Обработано 2900 из 5000 сэмплов.
# 	Обработано 3000 из 5000 сэмплов.
# 	Обработано 3100 из 5000 сэмплов.
# 	Обработано 3200 из 5000 сэмплов.
# 	Обработано 3300 из 5000 сэмплов.
# 	Обработано 3400 из 5000 сэмплов.
# 	Обработано 3500 из 5000 сэмплов.
# 	Обработано 3600 из 5000 сэмплов.
# 	Обработано 3700 из 5000 сэмплов.
# 	Обработано 3800 из 5000 сэмплов.
# 	Обработано 3900 из 5000 сэмплов.
# 	Обработано 4000 из 5000 сэмплов.
# 	Обработано 4100 из 5000 сэмплов.
# 	Обработано 4200 из 5000 сэмплов.
# 	Обработано 4300 из 5000 сэмплов.
# 	Обработано 4400 из 5000 сэмплов.
# 	Обработано 4500 из 5000 сэмплов.
# 	Обработано 4600 из 5000 сэмплов.
# 	Обработано 4700 из 5000 сэмплов.
# 	Обработано 4800 из 5000 сэмплов.
# 	Обработано 4900 из 5000 сэмплов.

# %%
# Evaluate the predictions in the `faster_rcnn` field of our `high_conf_view`
# with respect to the objects in the `ground_truth` field
results = val_dataset.evaluate_detections(
    "faster_rcnn",
    gt_field="detections",
    eval_key="eval",
    compute_mAP=True,
)
# Out:
# Evaluating detections...
#  100% |███████████████| 5000/5000 [20.8s elapsed, 0s remaining, 289.2 samples/s]
# Performing IoU sweep...
#  100% |███████████████| 5000/5000 [21.6s elapsed, 0s remaining, 262.6 samples/s]

# %%
# Для faster_rcnn оставляем только FP детекции
fp_detections = val_dataset.filter_labels("faster_rcnn", fo.ViewField("eval") == "fp")

# %%
session = fo.launch_app(fp_detections)

# %%
# Сохраняем файл с аннотацией FP Детекций
fp_detections.export(
    export_dir=os.path.join(dataset_path),
    dataset_type=fo.types.COCODetectionDataset,
    labels_path='val_anno_fp_detections.json',
    label_field='faster_rcnn',
    )
# Out:
# Directory 'data' already exists; export will be merged with existing files
#  100% |███████████████| 2803/2803 [8.4s elapsed, 0s remaining, 342.9 samples/s]

# %%
# Поменяем ссылки на существующие изображения в файле аннотации
# Каталог с сохраненными изображениями (dataset_path/data) можено удалить

with open(os.path.join(dataset_path, 'val_anno_fp_detections.json'), 'r') as read_file:
    val_anno_fp_detections = json.load(read_file)
read_file.close()
val_anno_fp_detections['images']

for i in range(len(val_anno_fp_detections['images'])):
    val_anno_fp_detections['images'][i]['file_name'] = 'rtsd-frames/' + val_anno_fp_detections['images'][i]['file_name']
val_anno_fp_detections['images']

with open(os.path.join(dataset_path, 'val_anno_fp_detections.json'), 'w') as f:
    json.dump(val_anno_fp_detections, f)#ensure_ascii=False, indent=4)
f.close()

# %%
# Смотрим итоговую аннотацию
with open(os.path.join(dataset_path, 'val_anno_fp_detections.json'), 'r') as read_file:
    val_anno_fp_detections = json.load(read_file)
read_file.close()
val_anno_fp_detections['images']
# Out:
# [{'id': 1,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_14_07.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 2,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_15_18.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 3,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_16_55.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 4,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_17_00.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 5,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_18_30.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 6,
#   'file_name': 'rtsd-frames/autosave01_02_2012_09_18_48.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id':
1.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 965,
#   'file_name': 'rtsd-frames/autosave10_10_2012_11_39_13_2.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 966,
#   'file_name': 'rtsd-frames/autosave10_10_2012_11_39_35_0.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 967,
#   'file_name': 'rtsd-frames/autosave10_10_2012_11_39_38_3.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 968,
#   'file_name': 'rtsd-frames/autosave10_10_2012_11_39_39_0.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 969,
#   'file_name': 'rtsd-frames/autosave10_10_2012_11_40_31_3.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 970,
#   'file_name': 'rtsd-frames/autosave10_10_2012_12_04_11_2.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 971,
#   'file_name': 'rtsd-frames/autosave10_10_2012_12_04_13_2.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 972,
#   'file_name': 'rtsd-frames/autosave10_10_2012_12_06_54_0.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 973,
#   'file_name': 'rtsd-frames/autosave10_10_2012_12_06_57_2.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 974,
#   'file_name': 'rtsd-frames/autosave10_10_2012_12_10_47_0.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 975,
#   'file_name': 'rtsd-frames/autosave10_10_2012_12_11_52_2.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 976,
#   'file_name': 'rtsd-frames/autosave10_10_2012_12_14_54_0.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 977,
#   'file_name': 'rtsd-frames/autosave10_10_2012_12_17_40_0.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 978,
#   'file_name': 'rtsd-frames/autosave10_10_2012_12_22_26_2.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 979,
#   'file_name': 'rtsd-frames/autosave10_10_2012_12_23_12_0.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 980,
#   'file_name': 'rtsd-frames/autosave10_10_2012_12_25_48_3.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 981,
#   'file_name': 'rtsd-frames/autosave10_10_2012_12_25_50_1.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 982,
#   'file_name': 'rtsd-frames/autosave10_10_2012_12_25_50_3.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 983,
#   'file_name': 'rtsd-frames/autosave10_10_2012_12_33_01_2.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 984,
#   'file_name': 'rtsd-frames/autosave10_10_2012_12_34_20_0.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 985,
#   'file_name': 'rtsd-frames/autosave10_10_2012_12_39_15_2.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 986,
#   'file_name': 'rtsd-frames/autosave10_10_2012_12_39_25_0.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 987,
#   'file_name': 'rtsd-frames/autosave10_10_2012_12_39_54_0.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 988,
#   'file_name': 'rtsd-frames/autosave10_10_2012_12_42_05_2.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 989,
#   'file_name': 'rtsd-frames/autosave10_10_2012_12_42_07_0.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 990,
#   'file_name': 'rtsd-frames/autosave10_10_2012_12_42_15_3.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 991,
#   'file_name': 'rtsd-frames/autosave10_10_2012_12_42_52_3.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 992,
#   'file_name': 'rtsd-frames/autosave10_10_2012_12_43_56_1.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 993,
#   'file_name': 'rtsd-frames/autosave10_10_2012_12_43_58_3.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 994,
#   'file_name': 'rtsd-frames/autosave10_10_2012_12_45_46_1.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 995,
#   'file_name': 'rtsd-frames/autosave10_10_2012_12_47_02_2.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 996,
#   'file_name': 'rtsd-frames/autosave10_10_2012_12_47_03_0.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 997,
#   'file_name': 'rtsd-frames/autosave10_10_2012_12_47_49_2.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 998,
#   'file_name': 'rtsd-frames/autosave10_10_2012_12_48_19_2.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 999,
#   'file_name': 'rtsd-frames/autosave10_10_2012_12_48_20_0.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  {'id': 1000,
#   'file_name': 'rtsd-frames/autosave10_10_2012_12_48_42_3.jpg',
#   'height': 720,
#   'width': 1280,
#   'license': None,
#   'coco_url': None},
#  ...]

# %% [markdown]
# ### Отбор реальных FP детекций

# %% [markdown]
# Загрузка датасета с FP детекциями

# %%
# загрузка датасета

# The directiry containing the source images
data_path = dataset_path     # можно не указывать, если в JSON путь совпадает

# The path yo the COCO labels JSON file
labels_file = 'val_anno_fp_detections.json'
labels_path = os.path.join(dataset_path, labels_file)


# Import the dataset
fp_detections_dataset = fo.Dataset.from_dir(
    dataset_type=fo.types.COCODetectionDataset,
    data_path=data_path,
    labels_path=labels_path
)
# Out:
#  100% |███████████████| 2803/2803 [5.6s elapsed, 0s remaining, 530.8 samples/s]

# %%
# Визуализация набора данных
# Для FP детекций (пойдут в фон классификатора) необходимо добавить label 'background'

session = fo.launch_app(fp_detections_dataset)

# %%
fp_detections_dataset.save
# Out:
# <bound method Dataset.save of Name:        2023.01.22.17.35.47
# Media type:  image
# Num samples: 2803
# Persistent:  False
# Tags:        []
# Sample fields:
#     id:         fiftyone.core.fields.ObjectIdField
#     filepath:   fiftyone.core.fields.StringField
#     tags:       fiftyone.core.fields.ListField(fiftyone.core.fields.StringField)
#     metadata:   fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.metadata.ImageMetadata)
#     detections: fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)>

# %%
for sample in fp_detections_dataset:
    detections = []
    for i in range(len(sample.detections.detections)):
        if 'background' in sample.detections.detections[i]['tags']:
            label = sample.detections.detections[i]['label']
            box = sample.detections.detections[i]['bounding_box']
            score = sample.detections.detections[i]['confidence']
            detections.append(fo.Detection(label=label,
                                        bounding_box=box,
                                        confidence=score
                                        )
                            )
        sample['background'] = fo.Detections(detections=detections)
        sample.save()

# %%
fp_detections_dataset.export(
    export_dir=os.path.join(dataset_path),
    dataset_type=fo.types.COCODetectionDataset,
    labels_path='val_anno_background.json',
    label_field='background',
    )
# Out:
# Directory 'data' already exists; export will be merged with existing files
# Found multiple fields ['detections', 'background'] with compatible type (<class 'fiftyone.core.labels.Detections'>, <class 'fiftyone.core.labels.Polylines'>, <class 'fiftyone.core.labels.Keypoints'>); exporting 'detections'

# %%
# Сохраняем файл с аннотацией FP Детекций
dataset_background = fp_detections_dataset.filter_labels('background', fo.ViewField("label") == "sign")
dataset_background.export(
    export_dir=os.path.join(dataset_path),
    dataset_type=fo.types.COCODetectionDataset,
    labels_path='val_anno_background.json',
    label_field='background',
)
# Out:
# Directory 'data' already exists; export will be merged with existing files
#  100% |███████████████| 1470/1470 [4.2s elapsed, 0s remaining, 436.7 samples/s]

# %%
dataset_background
# Out:
# Dataset:     2023.01.22.17.35.47
# Media type:  image
# Num samples: 1470
# Sample fields:
#     id:         fiftyone.core.fields.ObjectIdField
#     filepath:   fiftyone.core.fields.StringField
#     tags:       fiftyone.core.fields.ListField(fiftyone.core.fields.StringField)
#     metadata:   fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.metadata.ImageMetadata)
#     detections: fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)
#     background: fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)
# View stages:
#     1. FilterLabels(field='background', filter={'$eq': ['$$this.label', 'sign']}, only_matches=True, trajectories=False)

# %%
with open(os.path.join(dataset_path, 'val_anno_background.json'), 'r') as read_file:
    label_map = json.load(read_file)
read_file.close()
label_map['annotations'][-1]
# Out:
# {'id': 2082,
#  'image_id': 1470,
#  'category_id': 0,
#  'bbox': [941.7908935546875,
#   429.67187499999994,
#   20.73358154296875,
#   19.98858642578125],
#  'score': 0.06526462733745575,
#  'area': 414.4349865876138,
#  'iscrowd': 0}

# %%
# Поменяем ссылки на существующие изображения в файле аннотации
# Каталог с сохраненными изображениями (dataset_path/data) можено удалить

with open(os.path.join(dataset_path, 'val_anno_background.json'), 'r') as read_file:
    val_anno_background = json.load(read_file)
read_file.close()
val_anno_background['images']

for i in range(len(val_anno_background['images'])):
    val_anno_background['images'][i]['file_name'] = 'rtsd-frames/' + val_anno_background['images'][i]['file_name']
val_anno_background['images']

with open(os.path.join(dataset_path, 'val_anno_background.json'), 'w') as f:
    json.dump(val_anno_background, f)#ensure_ascii=False, indent=4)
f.close()
val_anno_background['images']

# %%
# загрузка датасета

# The directiry containing the source images
data_path = dataset_path      # можно не указывать, если в JSON путь совпадает

# The path yo the COCO labels JSON file
labels_file = "val_anno_background.json"
labels_path = os.path.join(dataset_path, labels_file)


# Import the dataset
dataset_background = fo.Dataset.from_dir(
    dataset_type=fo.types.COCODetectionDataset,
    data_path=data_path,
    labels_path=labels_path
)
# Out:
#  100% |███████████████| 1470/1470 [2.0s elapsed, 0s remaining, 714.8 samples/s]

# %%
# Визуализация набора данных
session = fo.launch_app(dataset_background)

# %%
dataset_background
# Out:
# Name:        2023.01.22.19.58.17
# Media type:  image
# Num samples: 1470
# Persistent:  False
# Tags:        []
# Sample fields:
#     id:         fiftyone.core.fields.ObjectIdField
#     filepath:   fiftyone.core.fields.StringField
#     tags:       fiftyone.core.fields.ListField(fiftyone.core.fields.StringField)
#     metadata:   fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.metadata.ImageMetadata)
#     detections: fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)
