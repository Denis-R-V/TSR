# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Denis-R-V/TSR/blob/main/simple_detector_v2.ipynb)

# %% [markdown]
# # Система распознавания дорожных знаков на датасете RTSD

# %%
import os
import json
import numpy as np 
import pandas as pd 

from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.patches as patches

from pycocotools.coco import COCO
import fiftyone as fo
import time
import torch
import torchvision
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection import FasterRCNN
import cv2

# %% [markdown]
# ## Обучение модели

# %%
import os
import torch
import torch.utils.data
import torchvision
from PIL import Image
from pycocotools.coco import COCO

# %%
class RTSD_dataset(torch.utils.data.Dataset):
    def __init__(self, root, annotation, transforms=None):
        super().__init__()
        self.root = root
        self.transforms = transforms
        self.coco = COCO(annotation)
        self.ids = list(sorted(self.coco.imgs.keys()))

    def __getitem__(self, index):
        # Own coco file
        coco = self.coco
        # Image ID
        img_id = self.ids[index]
        # List: get annotation id from coco
        ann_ids = coco.getAnnIds(imgIds=img_id)
        # Dictionary: target coco_annotation file for an image
        coco_annotation = coco.loadAnns(ann_ids)
        # path for input image
        path = coco.loadImgs(img_id)[0]['file_name']
        # open the input image
        img = Image.open(os.path.join(self.root, path))

        # number of objects in the image
        num_objs = len(coco_annotation)

        # Bounding boxes for objects
        # In coco format, bbox = [xmin, ymin, width, height]
        # In pytorch, the input should be [xmin, ymin, xmax, ymax]
        boxes = []
        for i in range(num_objs):
            xmin = coco_annotation[i]['bbox'][0]
            ymin = coco_annotation[i]['bbox'][1]
            xmax = xmin + coco_annotation[i]['bbox'][2]
            ymax = ymin + coco_annotation[i]['bbox'][3]
            boxes.append([xmin, ymin, xmax, ymax])
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        # Labels (In my case, I only one class: target class or background)
        labels = torch.ones((num_objs,), dtype=torch.int64)
        # Tensorise img_id
        img_id = torch.tensor([img_id])
        # Size of bbox (Rectangular)
        areas = []
        for i in range(num_objs):
            areas.append(coco_annotation[i]['area'])
        areas = torch.as_tensor(areas, dtype=torch.float32)
        # Iscrowd
        iscrowd = torch.zeros((num_objs,), dtype=torch.int64)

        # Annotation is in dictionary format
        my_annotation = {}
        my_annotation["boxes"] = boxes
        my_annotation["labels"] = labels
        my_annotation["image_id"] = img_id
        my_annotation["area"] = areas
        my_annotation["iscrowd"] = iscrowd

        if self.transforms is not None:
            img = self.transforms(img)

        return img, my_annotation

    def __len__(self):
        return len(self.ids)

# %%
# In my case, just added ToTensor
def get_transform():
    custom_transforms = []
    custom_transforms.append(torchvision.transforms.ToTensor())
    return torchvision.transforms.Compose(custom_transforms)

# %%
# path to your own data and coco file
train_data_dir = 'data'
train_coco = 'data/train_anno_reduced.json'

# create own Dataset
my_dataset = RTSD_dataset(root=train_data_dir,
                          annotation=train_coco,
                          transforms=get_transform()
                          )

# collate_fn needs for batch
def collate_fn(batch):
    return tuple(zip(*batch))

# Batch size
train_batch_size = 1

# own DataLoader
data_loader = torch.utils.data.DataLoader(my_dataset,
                                          batch_size=train_batch_size,
                                          shuffle=True,
                                          #num_workers=1,
                                          collate_fn=collate_fn)
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!

# %%
# select device (whether GPU or CPU)
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('mps')

# DataLoader is iterable over Dataset
for imgs, annotations in data_loader:
    imgs = list(img.to(device) for img in imgs)
    annotations = [{k: v.to(device) for k, v in t.items()} for t in annotations]
    print(annotations)
# Out:
# /opt/anaconda3/envs/ds_env/lib/python3.10/site-packages/torch/_tensor_str.py:115: UserWarning: The operator 'aten::nonzero' is not currently supported on the MPS backend and will fall back to run on the CPU. This may have performance implications. (Triggered internally at /Users/runner/work/_temp/anaconda/conda-bld/pytorch_1672474100825/work/aten/src/ATen/mps/MPSFallback.mm:11.)
#   nonzero_finite_vals = torch.masked_select(
# [{'boxes': tensor([[1215.,  483., 1239.,  519.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([27893], device='mps:0'), 'area': tensor([864.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1205.,  308., 1279.,  345.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([58775], device='mps:0'), 'area': tensor([2738.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[627., 282., 651., 317.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([38716], device='mps:0'), 'area': tensor([840.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[810., 354., 829., 372.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([8379], device='mps:0'), 'area': tensor([342.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[ 985.,  321., 1038.,  380.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([7776], device='mps:0'), 'area': tensor([3127.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1194.,  445., 1226.,  478.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([33274], device='mps:0'), 'area': tensor([1056.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[ 982.,  325., 1038.,  377.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([19502], device='mps:0'), 'area': tensor([2912.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[622., 369., 641., 390.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([45909], device='mps:0'), 'area': tensor([399.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1037.,  243., 1063.,  264.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([54738], device='mps:0'), 'area': tensor([546.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1752.,  523., 1814.,  549.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([30084], device='mps:0'), 'area': tensor([1612.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[763.,  21., 824.,  74.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([3568], device='mps:0'), 'area': tensor([3233.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1359.,  362., 1458.,  410.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([34144], device='mps:0'), 'area': tensor([4752.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[ 575.,  515.,  599.,  539.],
#         [1603.,  275., 1692.,  370.]], device='mps:0'), 'labels': tensor([1, 1], device='mps:0'), 'image_id': tensor([31009], device='mps:0'), 'area': tensor([ 576., 8455.], device='mps:0'), 'iscrowd': tensor([0, 0], device='mps:0')}]
# [{'boxes': tensor([[1000.,  356., 1038.,  421.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([57274], device='mps:0'), 'area': tensor([2470.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[ 991.,  299., 1025.,  315.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([42250], device='mps:0'), 'area': tensor([544.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[903., 247., 941., 288.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([43441], device='mps:0'), 'area': tensor([1558.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[947., 300., 967., 324.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([56590], device='mps:0'), 'area': tensor([480.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1164.,  239., 1227.,  299.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([18355], device='mps:0'), 'area': tensor([3780.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[ 933.,   55., 1020.,  180.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([41752], device='mps:0'), 'area': tensor([10875.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[921., 359., 945., 381.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([54193], device='mps:0'), 'area': tensor([528.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[773., 338., 791., 355.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([48087], device='mps:0'), 'area': tensor([306.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[408., 294., 433., 329.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([41440], device='mps:0'), 'area': tensor([875.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1254.,  174., 1353.,  256.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([34058], device='mps:0'), 'area': tensor([8118.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[794., 307., 821., 334.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([48785], device='mps:0'), 'area': tensor([729.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[812., 350., 854., 372.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([49624], device='mps:0'), 'area': tensor([924.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[396., 330., 417., 366.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([53646], device='mps:0'), 'area': tensor([756.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[ 988.,  325., 1018.,  358.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([44145], device='mps:0'), 'area': tensor([990.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1008.,  349., 1027.,  374.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([45784], device='mps:0'), 'area': tensor([475.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[866., 360., 894., 384.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([1781], device='mps:0'), 'area': tensor([672.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[640., 309., 658., 335.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([41715], device='mps:0'), 'area': tensor([468.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[828., 215., 903., 289.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([1259], device='mps:0'), 'area': tensor([5550.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[948., 297., 996., 321.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([20851], device='mps:0'), 'area': tensor([1152.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1053.,  375., 1074.,  393.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([52173], device='mps:0'), 'area': tensor([378.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[634., 289., 704., 323.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([21545], device='mps:0'), 'area': tensor([2380.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1133.,  178., 1189.,  197.],
#         [1133.,  178., 1189.,  197.]], device='mps:0'), 'labels': tensor([1, 1], device='mps:0'), 'image_id': tensor([54488], device='mps:0'), 'area': tensor([1064., 1064.], device='mps:0'), 'iscrowd': tensor([0, 0], device='mps:0')}]
# [{'boxes': tensor([[877., 204., 911., 252.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([3289], device='mps:0'), 'area': tensor([1632.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[361., 361., 387., 380.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([17794], device='mps:0'), 'area': tensor([494.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[690., 271., 710., 292.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([41761], device='mps:0'), 'area': tensor([420.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[575., 292., 596., 315.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([39040], device='mps:0'), 'area': tensor([483.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[765., 316., 787., 335.],
#         [765., 316., 787., 335.],
#         [765., 316., 787., 335.]], device='mps:0'), 'labels': tensor([1, 1, 1], device='mps:0'), 'image_id': tensor([7066], device='mps:0'), 'area': tensor([418., 418., 418.], device='mps:0'), 'iscrowd': tensor([0, 0, 0], device='mps:0')}]
# [{'boxes': tensor([[1615.,  151., 1744.,  222.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([31085], device='mps:0'), 'area': tensor([9159.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[868., 318., 908., 343.],
#         [874., 346., 907., 369.],
#         [874., 346., 907., 369.]], device='mps:0'), 'labels': tensor([1, 1, 1], device='mps:0'), 'image_id': tensor([299], device='mps:0'), 'area': tensor([1000.,  759.,  759.], device='mps:0'), 'iscrowd': tensor([0, 0, 0], device='mps:0')}]
# [{'boxes': tensor([[1404.,  485., 1474.,  521.],
#         [1404.,  485., 1474.,  521.]], device='mps:0'), 'labels': tensor([1, 1], device='mps:0'), 'image_id': tensor([30896], device='mps:0'), 'area': tensor([2520., 2520.], device='mps:0'), 'iscrowd': tensor([0, 0], device='mps:0')}]
# [{'boxes': tensor([[ 949.,  167., 1000.,  214.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([54419], device='mps:0'), 'area': tensor([2397.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[918., 347., 949., 381.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([7348], device='mps:0'), 'area': tensor([1054.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1212.,  284., 1231.,  315.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([4291], device='mps:0'), 'area': tensor([589.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[969., 220., 985., 236.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([40787], device='mps:0'), 'area': tensor([256.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[804., 303., 845., 322.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([36367], device='mps:0'), 'area': tensor([779.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1073.,  150., 1127.,  203.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([48188], device='mps:0'), 'area': tensor([2862.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[849., 293., 887., 336.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([43822], device='mps:0'), 'area': tensor([1634.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[108., 473., 143., 512.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([28359], device='mps:0'), 'area': tensor([1365.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1370.,  294., 1452.,  328.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([24365], device='mps:0'), 'area': tensor([2788.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[824., 315., 866., 354.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([1857], device='mps:0'), 'area': tensor([1638.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[846., 375., 888., 410.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([22838], device='mps:0'), 'area': tensor([1470.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[ 974.,  350., 1007.,  382.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([44877], device='mps:0'), 'area': tensor([1056.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[863., 270., 902., 307.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([9700], device='mps:0'), 'area': tensor([1443.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[896., 287., 947., 336.],
#         [900., 338., 950., 362.],
#         [900., 338., 950., 362.]], device='mps:0'), 'labels': tensor([1, 1, 1], device='mps:0'), 'image_id': tensor([58427], device='mps:0'), 'area': tensor([2499., 1200., 1200.], device='mps:0'), 'iscrowd': tensor([0, 0, 0], device='mps:0')}]
# [{'boxes': tensor([[728., 303., 747., 331.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([3451], device='mps:0'), 'area': tensor([532.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[825., 348., 849., 369.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([47286], device='mps:0'), 'area': tensor([504.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[ 980.,  305., 1010.,  352.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([43297], device='mps:0'), 'area': tensor([1410.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1463.,  384., 1521.,  437.],
#         [1463.,  384., 1521.,  437.]], device='mps:0'), 'labels': tensor([1, 1], device='mps:0'), 'image_id': tensor([30942], device='mps:0'), 'area': tensor([3074., 3074.], device='mps:0'), 'iscrowd': tensor([0, 0], device='mps:0')}]
# [{'boxes': tensor([[719., 268., 762., 308.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([2208], device='mps:0'), 'area': tensor([1720.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1139.,  311., 1209.,  373.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([58148], device='mps:0'), 'area': tensor([4340.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[836., 370., 853., 387.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([50083], device='mps:0'), 'area': tensor([289.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[766., 274., 801., 309.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([15905], device='mps:0'), 'area': tensor([1225.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[781., 369., 815., 386.],
#         [781., 369., 815., 386.],
#         [781., 369., 815., 386.]], device='mps:0'), 'labels': tensor([1, 1, 1], device='mps:0'), 'image_id': tensor([58426], device='mps:0'), 'area': tensor([578., 578., 578.], device='mps:0'), 'iscrowd': tensor([0, 0, 0], device='mps:0')}]
# [{'boxes': tensor([[876., 230., 919., 266.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([13873], device='mps:0'), 'area': tensor([1548.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[851., 387., 881., 444.],
#         [851., 387., 881., 444.]], device='mps:0'), 'labels': tensor([1, 1], device='mps:0'), 'image_id': tensor([23699], device='mps:0'), 'area': tensor([1710., 1710.], device='mps:0'), 'iscrowd': tensor([0, 0], device='mps:0')}]
# [{'boxes': tensor([[963., 255., 996., 282.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([3878], device='mps:0'), 'area': tensor([891.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[783., 376., 812., 402.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([17332], device='mps:0'), 'area': tensor([754.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[949., 549., 968., 573.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([29203], device='mps:0'), 'area': tensor([456.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[661., 528., 715., 571.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([34449], device='mps:0'), 'area': tensor([2322.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1235.,  262., 1256.,  284.],
#         [1236.,  238., 1257.,  261.]], device='mps:0'), 'labels': tensor([1, 1], device='mps:0'), 'image_id': tensor([54473], device='mps:0'), 'area': tensor([462., 483.], device='mps:0'), 'iscrowd': tensor([0, 0], device='mps:0')}]
# [{'boxes': tensor([[914., 359., 954., 399.],
#         [914., 359., 954., 399.]], device='mps:0'), 'labels': tensor([1, 1], device='mps:0'), 'image_id': tensor([18848], device='mps:0'), 'area': tensor([1600., 1600.], device='mps:0'), 'iscrowd': tensor([0, 0], device='mps:0')}]
# [{'boxes': tensor([[1118.,  242., 1155.,  280.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([36190], device='mps:0'), 'area': tensor([1406.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1115.,  495., 1139.,  512.],
#         [1167.,  358., 1232.,  383.]], device='mps:0'), 'labels': tensor([1, 1], device='mps:0'), 'image_id': tensor([34612], device='mps:0'), 'area': tensor([ 408., 1625.], device='mps:0'), 'iscrowd': tensor([0, 0], device='mps:0')}]
# [{'boxes': tensor([[436., 287., 459., 310.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([54864], device='mps:0'), 'area': tensor([529.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1704.,  251., 1808.,  393.],
#         [1704.,  251., 1808.,  393.]], device='mps:0'), 'labels': tensor([1, 1], device='mps:0'), 'image_id': tensor([28146], device='mps:0'), 'area': tensor([14768., 14768.], device='mps:0'), 'iscrowd': tensor([0, 0], device='mps:0')}]
# [{'boxes': tensor([[909., 326., 928., 345.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([55757], device='mps:0'), 'area': tensor([361.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1136.,  466., 1171.,  502.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([30368], device='mps:0'), 'area': tensor([1260.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1341.,  266., 1381.,  310.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([24318], device='mps:0'), 'area': tensor([1760.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[585., 331., 613., 358.],
#         [592., 301., 612., 331.]], device='mps:0'), 'labels': tensor([1, 1], device='mps:0'), 'image_id': tensor([38714], device='mps:0'), 'area': tensor([756., 600.], device='mps:0'), 'iscrowd': tensor([0, 0], device='mps:0')}]
# [{'boxes': tensor([[1077.,  306., 1158.,  381.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([18450], device='mps:0'), 'area': tensor([6075.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1004.,  184., 1120.,  276.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([49427], device='mps:0'), 'area': tensor([10672.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1172.,  284., 1230.,  339.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([31128], device='mps:0'), 'area': tensor([3190.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[922., 206., 976., 262.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([50878], device='mps:0'), 'area': tensor([3024.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1784.,    0., 1919.,  103.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([31113], device='mps:0'), 'area': tensor([13905.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[785., 303., 805., 335.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([53813], device='mps:0'), 'area': tensor([640.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1054.,  180., 1122.,  243.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([13229], device='mps:0'), 'area': tensor([4284.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[810., 174., 874., 220.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([3235], device='mps:0'), 'area': tensor([2944.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[933., 287., 985., 338.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([50851], device='mps:0'), 'area': tensor([2652.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[180., 383., 221., 422.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([18664], device='mps:0'), 'area': tensor([1599.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1541.,  445., 1628.,  482.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([29837], device='mps:0'), 'area': tensor([3219.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[927., 539., 943., 563.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([29202], device='mps:0'), 'area': tensor([384.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[324., 266., 358., 304.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([54021], device='mps:0'), 'area': tensor([1292.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[704.,  98., 752., 145.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([10066], device='mps:0'), 'area': tensor([2256.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[843., 422., 868., 476.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([7765], device='mps:0'), 'area': tensor([1350.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[705., 351., 766., 380.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([58084], device='mps:0'), 'area': tensor([1769.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[706., 380., 730., 414.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([19330], device='mps:0'), 'area': tensor([816.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[648., 264., 680., 297.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([15575], device='mps:0'), 'area': tensor([1056.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1204.,  370., 1285.,  396.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([34465], device='mps:0'), 'area': tensor([2106.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[712., 329., 743., 378.],
#         [712., 329., 743., 378.]], device='mps:0'), 'labels': tensor([1, 1], device='mps:0'), 'image_id': tensor([57700], device='mps:0'), 'area': tensor([1519., 1519.], device='mps:0'), 'iscrowd': tensor([0, 0], device='mps:0')}]
# [{'boxes': tensor([[1647.,  504., 1745.,  535.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([28633], device='mps:0'), 'area': tensor([3038.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[795., 345., 822., 361.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([281], device='mps:0'), 'area': tensor([432.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[642., 421., 670., 439.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([22277], device='mps:0'), 'area': tensor([504.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[772., 375., 815., 397.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([2671], device='mps:0'), 'area': tensor([946.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1154.,  382., 1230.,  424.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([24982], device='mps:0'), 'area': tensor([3192.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[240., 263., 282., 299.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([9047], device='mps:0'), 'area': tensor([1512.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[802., 335., 838., 370.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([49353], device='mps:0'), 'area': tensor([1260.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[478., 279., 499., 319.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([20728], device='mps:0'), 'area': tensor([840.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1019.,  421., 1047.,  451.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([34485], device='mps:0'), 'area': tensor([840.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[926., 285., 965., 326.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([6874], device='mps:0'), 'area': tensor([1599.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1018.,  567., 1053.,  586.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([30125], device='mps:0'), 'area': tensor([665.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[840., 175., 885., 222.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([68], device='mps:0'), 'area': tensor([2115.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[874., 250., 905., 297.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([8471], device='mps:0'), 'area': tensor([1457.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[808., 324., 839., 352.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([16927], device='mps:0'), 'area': tensor([868.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[645., 377., 663., 394.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([235], device='mps:0'), 'area': tensor([306.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[718., 349., 736., 367.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([5393], device='mps:0'), 'area': tensor([324.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[820., 225., 862., 288.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([10368], device='mps:0'), 'area': tensor([2646.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[638., 294., 689., 345.],
#         [638., 379., 686., 425.]], device='mps:0'), 'labels': tensor([1, 1], device='mps:0'), 'image_id': tensor([25050], device='mps:0'), 'area': tensor([2601., 2208.], device='mps:0'), 'iscrowd': tensor([0, 0], device='mps:0')}]
# [{'boxes': tensor([[1019.,  212., 1167.,  276.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([1483], device='mps:0'), 'area': tensor([9472.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1120.,  225., 1177.,  287.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([8939], device='mps:0'), 'area': tensor([3534.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1245.,  164., 1267.,  211.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([4259], device='mps:0'), 'area': tensor([1034.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1002.,  353., 1047.,  398.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([17348], device='mps:0'), 'area': tensor([2025.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[625., 371., 644., 391.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([15276], device='mps:0'), 'area': tensor([380.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[842., 312., 871., 348.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([12069], device='mps:0'), 'area': tensor([1044.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[ 632.,  296.,  654.,  319.],
#         [1146.,  226., 1179.,  268.],
#         [1146.,  226., 1179.,  268.]], device='mps:0'), 'labels': tensor([1, 1, 1], device='mps:0'), 'image_id': tensor([54911], device='mps:0'), 'area': tensor([ 506., 1386., 1386.], device='mps:0'), 'iscrowd': tensor([0, 0, 0], device='mps:0')}]
# [{'boxes': tensor([[689., 364., 712., 386.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([36438], device='mps:0'), 'area': tensor([506.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[894., 328., 930., 379.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([58195], device='mps:0'), 'area': tensor([1836.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[846., 334., 867., 350.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([51131], device='mps:0'), 'area': tensor([336.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[646., 369., 664., 387.],
#         [646., 369., 664., 387.],
#         [646., 369., 664., 387.],
#         [646., 369., 664., 387.],
#         [646., 369., 664., 387.]], device='mps:0'), 'labels': tensor([1, 1, 1, 1, 1], device='mps:0'), 'image_id': tensor([8236], device='mps:0'), 'area': tensor([324., 324., 324., 324., 324.], device='mps:0'), 'iscrowd': tensor([0, 0, 0, 0, 0], device='mps:0')}]
# [{'boxes': tensor([[381., 231., 409., 256.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([21877], device='mps:0'), 'area': tensor([700.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[953., 278., 979., 304.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([40359], device='mps:0'), 'area': tensor([676.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[795., 272., 831., 294.],
#         [795., 272., 831., 294.]], device='mps:0'), 'labels': tensor([1, 1], device='mps:0'), 'image_id': tensor([2173], device='mps:0'), 'area': tensor([792., 792.], device='mps:0'), 'iscrowd': tensor([0, 0], device='mps:0')}]
# [{'boxes': tensor([[1208.,  354., 1256.,  403.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([26408], device='mps:0'), 'area': tensor([2352.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[450., 289., 471., 310.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([11247], device='mps:0'), 'area': tensor([441.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[  0.,   0., 129., 105.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([39825], device='mps:0'), 'area': tensor([13545.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[370.,  24., 403.,  60.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([3502], device='mps:0'), 'area': tensor([1188.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1035.,  349., 1104.,  392.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([29089], device='mps:0'), 'area': tensor([2967.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[943., 375., 964., 396.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([49561], device='mps:0'), 'area': tensor([441.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[680., 320., 701., 342.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([14101], device='mps:0'), 'area': tensor([462.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1637.,  320., 1698.,  353.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([24257], device='mps:0'), 'area': tensor([2013.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[772., 394., 816., 438.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([44928], device='mps:0'), 'area': tensor([1936.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1112.,  346., 1152.,  376.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([23726], device='mps:0'), 'area': tensor([1200.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1035.,  326., 1058.,  352.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([44413], device='mps:0'), 'area': tensor([598.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[927., 314., 954., 337.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([44245], device='mps:0'), 'area': tensor([621.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1043.,  314., 1143.,  365.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([47125], device='mps:0'), 'area': tensor([5100.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[821., 349., 847., 373.],
#         [821., 349., 847., 373.]], device='mps:0'), 'labels': tensor([1, 1], device='mps:0'), 'image_id': tensor([7412], device='mps:0'), 'area': tensor([624., 624.], device='mps:0'), 'iscrowd': tensor([0, 0], device='mps:0')}]
# [{'boxes': tensor([[1026.,  346., 1052.,  392.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([49721], device='mps:0'), 'area': tensor([1196.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[638.,  61., 663.,  91.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([4434], device='mps:0'), 'area': tensor([750.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[359., 301., 391., 331.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([4200], device='mps:0'), 'area': tensor([960.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1204.,  375., 1227.,  397.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([19709], device='mps:0'), 'area': tensor([506.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1484.,  298., 1519.,  341.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([26621], device='mps:0'), 'area': tensor([1505.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[762., 345., 779., 372.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([7522], device='mps:0'), 'area': tensor([459.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[653., 247., 683., 272.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([4076], device='mps:0'), 'area': tensor([750.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[969., 246., 996., 272.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([40099], device='mps:0'), 'area': tensor([702.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1425.,  101., 1548.,  210.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([34633], device='mps:0'), 'area': tensor([13407.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[895., 143., 972., 219.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([37072], device='mps:0'), 'area': tensor([5852.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[ 966.,  191., 1045.,  301.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([38101], device='mps:0'), 'area': tensor([8690.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1203.,  345., 1228.,  385.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([49257], device='mps:0'), 'area': tensor([1000.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[956., 244., 978., 265.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([54312], device='mps:0'), 'area': tensor([462.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[964., 353., 983., 371.],
#         [964., 353., 983., 371.]], device='mps:0'), 'labels': tensor([1, 1], device='mps:0'), 'image_id': tensor([46487], device='mps:0'), 'area': tensor([342., 342.], device='mps:0'), 'iscrowd': tensor([0, 0], device='mps:0')}]
# [{'boxes': tensor([[746., 327., 766., 349.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([11302], device='mps:0'), 'area': tensor([440.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[896., 252., 935., 292.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([51640], device='mps:0'), 'area': tensor([1560.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[691., 406., 713., 429.],
#         [690., 384., 711., 406.]], device='mps:0'), 'labels': tensor([1, 1], device='mps:0'), 'image_id': tensor([22236], device='mps:0'), 'area': tensor([506., 462.], device='mps:0'), 'iscrowd': tensor([0, 0], device='mps:0')}]
# [{'boxes': tensor([[719., 341., 736., 359.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([6080], device='mps:0'), 'area': tensor([306.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1171.,  237., 1231.,  297.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([22761], device='mps:0'), 'area': tensor([3600.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1028.,  317., 1065.,  375.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([57592], device='mps:0'), 'area': tensor([2146.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1310.,  456., 1339.,  484.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([33437], device='mps:0'), 'area': tensor([812.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[815., 203., 874., 233.],
#         [815., 203., 874., 233.],
#         [815., 203., 874., 233.],
#         [815., 203., 874., 233.],
#         [815., 203., 874., 233.],
#         [815., 203., 874., 233.]], device='mps:0'), 'labels': tensor([1, 1, 1, 1, 1, 1], device='mps:0'), 'image_id': tensor([18474], device='mps:0'), 'area': tensor([1770., 1770., 1770., 1770., 1770., 1770.], device='mps:0'), 'iscrowd': tensor([0, 0, 0, 0, 0, 0], device='mps:0')}]
# [{'boxes': tensor([[1451.,  389., 1483.,  442.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([25740], device='mps:0'), 'area': tensor([1696.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[781., 264., 816., 297.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([13231], device='mps:0'), 'area': tensor([1155.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1882.,  345., 1906.,  379.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([25297], device='mps:0'), 'area': tensor([816.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[863., 329., 899., 389.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([57452], device='mps:0'), 'area': tensor([2160.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[961., 322., 992., 352.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([14933], device='mps:0'), 'area': tensor([930.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1106.,  286., 1142.,  322.],
#         [1106.,  286., 1142.,  322.]], device='mps:0'), 'labels': tensor([1, 1], device='mps:0'), 'image_id': tensor([40555], device='mps:0'), 'area': tensor([1296., 1296.], device='mps:0'), 'iscrowd': tensor([0, 0], device='mps:0')}]
# [{'boxes': tensor([[763., 366., 783., 384.],
#         [763., 366., 783., 384.]], device='mps:0'), 'labels': tensor([1, 1], device='mps:0'), 'image_id': tensor([52533], device='mps:0'), 'area': tensor([360., 360.], device='mps:0'), 'iscrowd': tensor([0, 0], device='mps:0')}]
# [{'boxes': tensor([[905., 316., 945., 350.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([51319], device='mps:0'), 'area': tensor([1360.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[861., 369., 900., 407.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([22203], device='mps:0'), 'area': tensor([1482.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[701., 340., 751., 383.],
#         [701., 340., 751., 383.]], device='mps:0'), 'labels': tensor([1, 1], device='mps:0'), 'image_id': tensor([59033], device='mps:0'), 'area': tensor([2150., 2150.], device='mps:0'), 'iscrowd': tensor([0, 0], device='mps:0')}]
# [{'boxes': tensor([[1092.,  107., 1156.,  204.],
#         [1092.,  107., 1156.,  204.]], device='mps:0'), 'labels': tensor([1, 1], device='mps:0'), 'image_id': tensor([4364], device='mps:0'), 'area': tensor([6208., 6208.], device='mps:0'), 'iscrowd': tensor([0, 0], device='mps:0')}]
# [{'boxes': tensor([[642., 403., 666., 426.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([36021], device='mps:0'), 'area': tensor([552.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[763., 278., 807., 300.],
#         [762., 254., 807., 276.],
#         [762., 254., 807., 276.],
#         [762., 254., 807., 276.]], device='mps:0'), 'labels': tensor([1, 1, 1, 1], device='mps:0'), 'image_id': tensor([18472], device='mps:0'), 'area': tensor([968., 990., 990., 990.], device='mps:0'), 'iscrowd': tensor([0, 0, 0, 0], device='mps:0')}]
# [{'boxes': tensor([[1242.,  301., 1280.,  345.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([11756], device='mps:0'), 'area': tensor([1672.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[858., 290., 898., 333.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([57444], device='mps:0'), 'area': tensor([1720.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[ 981.,  555.,  999.,  572.],
#         [1073.,  528., 1120.,  549.]], device='mps:0'), 'labels': tensor([1, 1], device='mps:0'), 'image_id': tensor([31003], device='mps:0'), 'area': tensor([306., 987.], device='mps:0'), 'iscrowd': tensor([0, 0], device='mps:0')}]
# [{'boxes': tensor([[931., 142., 964., 164.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([41770], device='mps:0'), 'area': tensor([726.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[628., 328., 646., 349.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([105], device='mps:0'), 'area': tensor([378.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[934., 394., 992., 447.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([15505], device='mps:0'), 'area': tensor([3074.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[763., 282., 794., 299.],
#         [763., 282., 794., 299.]], device='mps:0'), 'labels': tensor([1, 1], device='mps:0'), 'image_id': tensor([19641], device='mps:0'), 'area': tensor([527., 527.], device='mps:0'), 'iscrowd': tensor([0, 0], device='mps:0')}]
# [{'boxes': tensor([[ 992.,  324., 1031.,  361.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([332], device='mps:0'), 'area': tensor([1443.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1049.,  217., 1075.,  243.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([40653], device='mps:0'), 'area': tensor([676.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[790., 260., 835., 309.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([20436], device='mps:0'), 'area': tensor([2205.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1152.,  375., 1204.,  441.],
#         [1152.,  375., 1204.,  441.]], device='mps:0'), 'labels': tensor([1, 1], device='mps:0'), 'image_id': tensor([29994], device='mps:0'), 'area': tensor([3432., 3432.], device='mps:0'), 'iscrowd': tensor([0, 0], device='mps:0')}]
# [{'boxes': tensor([[813., 332., 842., 359.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([57236], device='mps:0'), 'area': tensor([783.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1025.,  345., 1058.,  378.],
#         [1025.,  345., 1058.,  378.]], device='mps:0'), 'labels': tensor([1, 1], device='mps:0'), 'image_id': tensor([20980], device='mps:0'), 'area': tensor([1089., 1089.], device='mps:0'), 'iscrowd': tensor([0, 0], device='mps:0')}]
# [{'boxes': tensor([[729., 324., 746., 342.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([9870], device='mps:0'), 'area': tensor([306.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# ...
# [{'boxes': tensor([[1230.,  230., 1279.,  318.],
#         [1230.,  230., 1279.,  318.],
#         [1230.,  230., 1279.,  318.]], device='mps:0'), 'labels': tensor([1, 1, 1], device='mps:0'), 'image_id': tensor([7556], device='mps:0'), 'area': tensor([4312., 4312., 4312.], device='mps:0'), 'iscrowd': tensor([0, 0, 0], device='mps:0')}]
# [{'boxes': tensor([[819., 311., 853., 343.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([9695], device='mps:0'), 'area': tensor([1088.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[809., 319., 829., 357.],
#         [809., 319., 829., 357.],
#         [809., 319., 829., 357.],
#         [809., 319., 829., 357.]], device='mps:0'), 'labels': tensor([1, 1, 1, 1], device='mps:0'), 'image_id': tensor([38146], device='mps:0'), 'area': tensor([760., 760., 760., 760.], device='mps:0'), 'iscrowd': tensor([0, 0, 0, 0], device='mps:0')}]
# [{'boxes': tensor([[1169.,  347., 1211.,  392.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([24220], device='mps:0'), 'area': tensor([1890.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1187.,  195., 1225.,  248.],
#         [1187.,  195., 1225.,  248.]], device='mps:0'), 'labels': tensor([1, 1], device='mps:0'), 'image_id': tensor([54912], device='mps:0'), 'area': tensor([2014., 2014.], device='mps:0'), 'iscrowd': tensor([0, 0], device='mps:0')}]
# [{'boxes': tensor([[711., 198., 762., 227.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([38966], device='mps:0'), 'area': tensor([1479.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[649., 358., 673., 381.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([57298], device='mps:0'), 'area': tensor([552.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1005.,  425., 1029.,  450.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([34484], device='mps:0'), 'area': tensor([600.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[ 76., 271., 141., 336.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([24830], device='mps:0'), 'area': tensor([4225.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[817., 298., 866., 349.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([9744], device='mps:0'), 'area': tensor([2499.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[720., 339., 740., 358.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([11801], device='mps:0'), 'area': tensor([380.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[739., 262., 789., 318.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([38804], device='mps:0'), 'area': tensor([2800.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[683., 272., 715., 320.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([41055], device='mps:0'), 'area': tensor([1536.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[673., 358., 689., 374.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([8194], device='mps:0'), 'area': tensor([256.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[920., 284., 946., 310.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([51943], device='mps:0'), 'area': tensor([676.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[945., 359., 975., 382.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([48620], device='mps:0'), 'area': tensor([690.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[  0., 218.,  94., 325.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([31021], device='mps:0'), 'area': tensor([10058.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[555., 313., 573., 339.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([38712], device='mps:0'), 'area': tensor([468.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[772., 256., 795., 279.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([13899], device='mps:0'), 'area': tensor([529.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1196.,  423., 1226.,  456.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([26453], device='mps:0'), 'area': tensor([990.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[684., 312., 706., 336.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([9986], device='mps:0'), 'area': tensor([528.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[ 982.,  355., 1011.,  385.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([50977], device='mps:0'), 'area': tensor([870.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[806., 283., 856., 329.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([10966], device='mps:0'), 'area': tensor([2300.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[694., 308., 760., 368.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([16311], device='mps:0'), 'area': tensor([3960.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1119.,  256., 1193.,  321.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([7015], device='mps:0'), 'area': tensor([4810.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1002.,  305., 1034.,  335.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([41597], device='mps:0'), 'area': tensor([960.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1108.,  189., 1210.,  239.],
#         [1108.,  189., 1210.,  239.],
#         [1108.,  189., 1210.,  239.],
#         [1108.,  189., 1210.,  239.],
#         [1108.,  189., 1210.,  239.],
#         [1108.,  189., 1210.,  239.],
#         [1108.,  189., 1210.,  239.]], device='mps:0'), 'labels': tensor([1, 1, 1, 1, 1, 1, 1], device='mps:0'), 'image_id': tensor([47302], device='mps:0'), 'area': tensor([5100., 5100., 5100., 5100., 5100., 5100., 5100.], device='mps:0'), 'iscrowd': tensor([0, 0, 0, 0, 0, 0, 0], device='mps:0')}]
# [{'boxes': tensor([[1057.,  244., 1131.,  307.],
#         [1057.,  244., 1131.,  307.]], device='mps:0'), 'labels': tensor([1, 1], device='mps:0'), 'image_id': tensor([51138], device='mps:0'), 'area': tensor([4662., 4662.], device='mps:0'), 'iscrowd': tensor([0, 0], device='mps:0')}]
# [{'boxes': tensor([[713., 332., 744., 362.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([239], device='mps:0'), 'area': tensor([930.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[924., 292., 945., 315.],
#         [924., 292., 945., 315.]], device='mps:0'), 'labels': tensor([1, 1], device='mps:0'), 'image_id': tensor([41593], device='mps:0'), 'area': tensor([483., 483.], device='mps:0'), 'iscrowd': tensor([0, 0], device='mps:0')}]
# [{'boxes': tensor([[773., 346., 794., 368.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([5639], device='mps:0'), 'area': tensor([462.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1036.,  298., 1073.,  318.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([55651], device='mps:0'), 'area': tensor([740.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[404., 408., 451., 454.],
#         [404., 408., 451., 454.]], device='mps:0'), 'labels': tensor([1, 1], device='mps:0'), 'image_id': tensor([31017], device='mps:0'), 'area': tensor([2162., 2162.], device='mps:0'), 'iscrowd': tensor([0, 0], device='mps:0')}]
# [{'boxes': tensor([[844., 371., 872., 422.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([56975], device='mps:0'), 'area': tensor([1428.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1237.,  343., 1257.,  366.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([44535], device='mps:0'), 'area': tensor([460.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1218.,  237., 1278.,  268.],
#         [ 552.,  515.,  579.,  531.]], device='mps:0'), 'labels': tensor([1, 1], device='mps:0'), 'image_id': tensor([26651], device='mps:0'), 'area': tensor([1860.,  432.], device='mps:0'), 'iscrowd': tensor([0, 0], device='mps:0')}]
# [{'boxes': tensor([[954., 300., 989., 334.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([8615], device='mps:0'), 'area': tensor([1190.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[ 989.,  246., 1031.,  314.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([15654], device='mps:0'), 'area': tensor([2856.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[709., 308., 743., 355.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([38096], device='mps:0'), 'area': tensor([1598.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[ 994.,  255., 1035.,  293.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([53699], device='mps:0'), 'area': tensor([1558.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[756., 383., 782., 410.],
#         [756., 383., 782., 410.]], device='mps:0'), 'labels': tensor([1, 1], device='mps:0'), 'image_id': tensor([19499], device='mps:0'), 'area': tensor([702., 702.], device='mps:0'), 'iscrowd': tensor([0, 0], device='mps:0')}]
# [{'boxes': tensor([[1009.,  217., 1052.,  241.],
#         [1009.,  217., 1052.,  241.]], device='mps:0'), 'labels': tensor([1, 1], device='mps:0'), 'image_id': tensor([54543], device='mps:0'), 'area': tensor([1032., 1032.], device='mps:0'), 'iscrowd': tensor([0, 0], device='mps:0')}]
# [{'boxes': tensor([[879., 309., 928., 351.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([21733], device='mps:0'), 'area': tensor([2058.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[629., 309., 648., 337.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([41745], device='mps:0'), 'area': tensor([532.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1229.,  342., 1277.,  364.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([28309], device='mps:0'), 'area': tensor([1056.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[836., 376., 854., 403.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([18569], device='mps:0'), 'area': tensor([486.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[645., 300., 666., 321.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([21775], device='mps:0'), 'area': tensor([441.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1208.,  165., 1248.,  185.],
#         [1208.,  165., 1248.,  185.],
#         [1208.,  165., 1248.,  185.]], device='mps:0'), 'labels': tensor([1, 1, 1], device='mps:0'), 'image_id': tensor([53931], device='mps:0'), 'area': tensor([800., 800., 800.], device='mps:0'), 'iscrowd': tensor([0, 0, 0], device='mps:0')}]
# [{'boxes': tensor([[731., 377., 771., 414.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([16432], device='mps:0'), 'area': tensor([1480.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[712., 534., 729., 552.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([30227], device='mps:0'), 'area': tensor([306.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[970., 281., 986., 297.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([56269], device='mps:0'), 'area': tensor([256.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[792., 322., 813., 354.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([7542], device='mps:0'), 'area': tensor([672.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1214.,  265., 1258.,  311.],
#         [1214.,  265., 1258.,  311.]], device='mps:0'), 'labels': tensor([1, 1], device='mps:0'), 'image_id': tensor([40557], device='mps:0'), 'area': tensor([2024., 2024.], device='mps:0'), 'iscrowd': tensor([0, 0], device='mps:0')}]
# [{'boxes': tensor([[716., 266., 735., 285.],
#         [716., 266., 735., 285.]], device='mps:0'), 'labels': tensor([1, 1], device='mps:0'), 'image_id': tensor([16164], device='mps:0'), 'area': tensor([361., 361.], device='mps:0'), 'iscrowd': tensor([0, 0], device='mps:0')}]
# [{'boxes': tensor([[617., 306., 638., 333.],
#         [617., 306., 638., 333.]], device='mps:0'), 'labels': tensor([1, 1], device='mps:0'), 'image_id': tensor([38349], device='mps:0'), 'area': tensor([567., 567.], device='mps:0'), 'iscrowd': tensor([0, 0], device='mps:0')}]
# [{'boxes': tensor([[1115.,  556., 1143.,  572.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([29250], device='mps:0'), 'area': tensor([448.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1683.,  307., 1767.,  330.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([24756], device='mps:0'), 'area': tensor([1932.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[746., 385., 770., 424.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([18794], device='mps:0'), 'area': tensor([936.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1113.,  241., 1141.,  277.],
#         [1113.,  241., 1141.,  277.],
#         [1113.,  241., 1141.,  277.]], device='mps:0'), 'labels': tensor([1, 1, 1], device='mps:0'), 'image_id': tensor([54910], device='mps:0'), 'area': tensor([1008., 1008., 1008.], device='mps:0'), 'iscrowd': tensor([0, 0, 0], device='mps:0')}]
# [{'boxes': tensor([[ 972.,   63., 1035.,  125.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([7726], device='mps:0'), 'area': tensor([3906.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1013.,  205., 1054.,  249.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([35947], device='mps:0'), 'area': tensor([1804.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[1003.,  313., 1033.,  329.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([56592], device='mps:0'), 'area': tensor([480.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[685., 377., 709., 400.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([22925], device='mps:0'), 'area': tensor([552.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]
# [{'boxes': tensor([[742., 368., 758., 389.]], device='mps:0'), 'labels': tensor([1], device='mps:0'), 'image_id': tensor([49018], device='mps:0'), 'area': tensor([336.], device='mps:0'), 'iscrowd': tensor([0], device='mps:0')}]

# %%
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

def get_model_instance_segmentation(num_classes):
    # load an instance segmentation model pre-trained pre-trained on COCO
    model = torchvision.models.detection.fasterrcnn_resnet50_fpn(weights=None)
    # get number of input features for the classifier
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    # replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

    return model
    

# 2 classes; Only target class or background
num_classes = 156
num_epochs = 10
model = get_model_instance_segmentation(num_classes)

# move model to the right device
model.to(device)
    
# parameters
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005, momentum=0.9, weight_decay=0.0005)

len_dataloader = len(data_loader)

for epoch in range(num_epochs):
    model.train()
    i = 0    
    for imgs, annotations in data_loader:
        i += 1
        imgs = list(img.to(device) for img in imgs)
        annotations = [{k: v.to(device) for k, v in t.items()} for t in annotations]
        loss_dict = model(imgs, annotations)
        losses = sum(loss for loss in loss_dict.values())

        optimizer.zero_grad()
        losses.backward()
        optimizer.step()

        print(f'Iteration: {i}/{len_dataloader}, Loss: {losses}')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 35
#      33 imgs = list(img.to(device) for img in imgs)
#      34 annotations = [{k: v.to(device) for k, v in t.items()} for t in annotations]
# ---> 35 loss_dict = model(imgs, annotations)
#      36 losses = sum(loss for loss in loss_dict.values())
#      38 optimizer.zero_grad()
#
# File /opt/anaconda3/envs/ds_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1482, in Module._call_impl(self, *args, **kwargs)
#    1477 # If we don't have any hooks, we want to skip the rest of the logic in
#    1478 # this function, and just call forward.
#    1479 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1480         or _global_backward_pre_hooks or _global_backward_hooks
#    1481         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1482     return forward_call(*args, **kwargs)
#    1483 # Do not call functions when jit is used
#    1484 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/anaconda3/envs/ds_env/lib/python3.10/site-packages/torchvision/models/detection/generalized_rcnn.py:104, in GeneralizedRCNN.forward(self, images, targets)
#     102 if isinstance(features, torch.Tensor):
#     103     features = OrderedDict([("0", features)])
# --> 104 proposals, proposal_losses = self.rpn(images, features, targets)
#     105 detections, detector_losses = self.roi_heads(features, proposals, images.image_sizes, targets)
#     106 detections = self.transform.postprocess(detections, images.image_sizes, original_image_sizes)  # type: ignore[operator]
#
# File /opt/anaconda3/envs/ds_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1482, in Module._call_impl(self, *args, **kwargs)
#    1477 # If we don't have any hooks, we want to skip the rest of the logic in
#    1478 # this function, and just call forward.
#    1479 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1480         or _global_backward_pre_hooks or _global_backward_hooks
#    1481         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1482     return forward_call(*args, **kwargs)
#    1483 # Do not call functions when jit is used
#    1484 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/anaconda3/envs/ds_env/lib/python3.10/site-packages/torchvision/models/detection/rpn.py:372, in RegionProposalNetwork.forward(self, images, features, targets)
#     370 proposals = self.box_coder.decode(pred_bbox_deltas.detach(), anchors)
#     371 proposals = proposals.view(num_images, -1, 4)
# --> 372 boxes, scores = self.filter_proposals(proposals, objectness, images.image_sizes, num_anchors_per_level)
#     374 losses = {}
#     375 if self.training:
#
# File /opt/anaconda3/envs/ds_env/lib/python3.10/site-packages/torchvision/models/detection/rpn.py:262, in RegionProposalNetwork.filter_proposals(self, proposals, objectness, image_shapes, num_anchors_per_level)
#     259 levels = levels.reshape(1, -1).expand_as(objectness)
#     261 # select top_n boxes independently per level before applying nms
# --> 262 top_n_idx = self._get_top_n_idx(objectness, num_anchors_per_level)
#     264 image_range = torch.arange(num_images, device=device)
#     265 batch_idx = image_range[:, None]
#
# File /opt/anaconda3/envs/ds_env/lib/python3.10/site-packages/torchvision/models/detection/rpn.py:236, in RegionProposalNetwork._get_top_n_idx(self, objectness, num_anchors_per_level)
#     234 num_anchors = ob.shape[1]
#     235 pre_nms_top_n = det_utils._topk_min(ob, self.pre_nms_top_n(), 1)
# --> 236 _, top_n_idx = ob.topk(pre_nms_top_n, dim=1)
#     237 r.append(top_n_idx + offset)
#     238 offset += num_anchors
#
# RuntimeError: Currently topk on mps works only for k<=16

# %%
# data loader
batch_size = 1
num_workers = 4

data_loader = torch.utils.data.DataLoader(my_dataset,
                                          batch_size=batch_size,
                                          shuffle=False,
                                          num_workers=num_workers
                                         )


import numpy as np
import matplotlib.pyplot as plt

for images, labels in data_loader:
    # image shape is [batch_size, 3 (due to RGB), height, width]
    img = transforms.ToPILImage()(images[0])
    plt.imshow(img)
    plt.show()
    print(labels)
# Out:
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/opt/anaconda3/envs/ds_env/lib/python3.10/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/opt/anaconda3/envs/ds_env/lib/python3.10/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
# AttributeError: Can't get attribute 'RTSD_dataset' on <module '__main__' (built-in)>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 15
#      12 import numpy as np
#      13 import matplotlib.pyplot as plt
# ---> 15 for images, labels in data_loader:
#      16     # image shape is [batch_size, 3 (due to RGB), height, width]
#      17     img = transforms.ToPILImage()(images[0])
#      18     plt.imshow(img)
#
# File /opt/anaconda3/envs/ds_env/lib/python3.10/site-packages/torch/utils/data/dataloader.py:443, in DataLoader.__iter__(self)
#     441     return self._iterator
#     442 else:
# --> 443     return self._get_iterator()
#
# File /opt/anaconda3/envs/ds_env/lib/python3.10/site-packages/torch/utils/data/dataloader.py:389, in DataLoader._get_iterator(self)
#     387 else:
#     388     self.check_worker_number_rationality()
# --> 389     return _MultiProcessingDataLoaderIter(self)
#
# File /opt/anaconda3/envs/ds_env/lib/python3.10/site-packages/torch/utils/data/dataloader.py:1044, in _MultiProcessingDataLoaderIter.__init__(self, loader)
#    1037 w.daemon = True
#    1038 # NB: Process.start() actually take some time as it needs to
#    1039 #     start a process and pass the arguments over via a pipe.
#    1040 #     Therefore, we only add a worker to self._workers list after
#    1041 #     it started, so that we do not call .join() if program dies
#    1042 #     before it starts, and __del__ tries to join but will get:
#    1043 #     AssertionError: can only join a started process.
# -> 1044 w.start()
#    1045 self._index_queues.append(index_queue)
#    1046 self._workers.append(w)
#
# File /opt/anaconda3/envs/ds_env/lib/python3.10/multiprocessing/process.py:121, in BaseProcess.start(self)
#     118 assert not _current_process._config.get('daemon'), \
#     119        'daemonic processes are not allowed to have children'
#     120 _cleanup()
# --> 121 self._popen = self._Popen(self)
#     122 self._sentinel = self._popen.sentinel
#     123 # Avoid a refcycle if the target function holds an indirect
#     124 # reference to the process object (see bpo-30775)
#
# File /opt/anaconda3/envs/ds_env/lib/python3.10/multiprocessing/context.py:224, in Process._Popen(process_obj)
#     222 @staticmethod
#     223 def _Popen(process_obj):
# --> 224     return _default_context.get_context().Process._Popen(process_obj)
#
# File /opt/anaconda3/envs/ds_env/lib/python3.10/multiprocessing/context.py:288, in SpawnProcess._Popen(process_obj)
#     285 @staticmethod
#     286 def _Popen(process_obj):
#     287     from .popen_spawn_posix import Popen
# --> 288     return Popen(process_obj)
#
# File /opt/anaconda3/envs/ds_env/lib/python3.10/multiprocessing/popen_spawn_posix.py:32, in Popen.__init__(self, process_obj)
#      30 def __init__(self, process_obj):
#      31     self._fds = []
# ---> 32     super().__init__(process_obj)
#
# File /opt/anaconda3/envs/ds_env/lib/python3.10/multiprocessing/popen_fork.py:19, in Popen.__init__(self, process_obj)
#      17 self.returncode = None
#      18 self.finalizer = None
# ---> 19 self._launch(process_obj)
#
# File /opt/anaconda3/envs/ds_env/lib/python3.10/multiprocessing/popen_spawn_posix.py:62, in Popen._launch(self, process_obj)
#      60     self.sentinel = parent_r
#      61     with open(parent_w, 'wb', closefd=False) as f:
# ---> 62         f.write(fp.getbuffer())
#      63 finally:
#      64     fds_to_close = []
#
# KeyboardInterrupt:
